# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/VLF/blob/main/VLF_fits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install astropy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#@markdown `imports`
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt             
# %matplotlib inline
import seaborn as sns
import matplotlib.ticker as ticker

from datetime import datetime as dt

path = 'https://github.com/Rogerio-mack/Temporal/raw/main/Data/'
plt.style.use(['https://github.com/Rogerio-mack/Temporal/raw/main/tsp.mplstyle' ])

# Para ver os parâmetros empregados aqui
# plt.rcParams
# plt.rcParams['figure.figsize']

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
# !gunzip /content/PIU-20080104.fits.gz
# Out:
# gzip: /content/PIU-20080104.fits.gz: No such file or directory

# %%
from astropy.io import fits
fx = fits.open('/content/PIU-20080104.fits', memmap=True)

# %%
fx.info()
# Out:
# Filename: /content/PIU-20080104.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (16, 52681)   float32

# %%
fx[0].data.shape
# Out:
# (52681, 16)

# %%
import pandas as pd

pd.DataFrame(fx[0].data)
# Out:
#             0     1           2          3           4          5   \
# 0          0.0 -0.02   47.900002  30.900000 -120.620003  22.020000
# 1          1.0  0.01   49.320000  30.870001 -121.059998  21.910000
# 2          2.0 -0.01   48.360001  30.959999 -120.980003  22.160000
# 3          3.0 -0.02   48.730000  30.920000 -120.070000  21.850000
# 4          4.0  0.01   49.400002  30.850000 -120.809998  21.959999
# ...        ...   ...         ...        ...         ...        ...
# 52676  52676.0  0.01  569.210022  35.450001  -87.730003  23.070000
# 52677  52677.0  0.04  569.200012  35.540001  -88.500000  22.980000
# 52678  52678.0  0.02  569.299988  35.500000  -88.389999  22.920000
# 52679  52679.0 -0.02  568.780029  35.500000  -88.430000  22.990000
# 52680  52680.0 -0.02  569.419983  35.450001  -90.180000  22.790001
#
#                6          7          8     9           10     11          12  \
# 0       36.310001  15.650000  48.419998  7.17    0.870000  12.94 -178.410004
# ...

# %%
fx[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  21-Jan-2008 11:58:10.00
# BITPIX  =                  -32 /
# NAXIS   =                    2 /
# NAXIS1  =                   16 /
# NAXIS2  =                52681 /
# DATE    = '21/01/08'           / Creation date (DD/MM/YY) of FITS header
# DATE-OBS= '2008-01-04'         /
# STATION = 'piura   '           /
# COL-1   = 'Time-UT (s)'        /
# COL-2   = 'GPS Delay (us)'     /
# COL-3   = 'NAA-V Phase (deg.)' /
# COL-4   = 'NAA-V Amp (dB)'     /
# COL-5   = 'NDK-V Phase (deg.)' /
# COL-6   = 'NDK-V Amp (dB)'     /
# COL-7   = 'NAA-L Phase (deg.)' /
# COL-8   = 'NAA-L Amp (dB)'     /
# COL-9   = 'NDK-L Phase (deg.)' /
# COL-10  = 'NDK-L Amp (dB)'     /
# COL-11  = 'NAU Phase (deg.)'   /
# COL-12  = 'NAU Amp (dB)'       /
# COL-13  = 'NLK Phase (deg.)'   /
# COL-14  = 'NLK Amp (dB)'       /
# COL-15  = 'NPM Phase (deg.)'   /
# COL-16  = 'NPM Amp (dB)'       /

# %%
header = []
for a in fx[0].header.values():
  header.append(str(a))
#  print(a)

# %%
for i in range(len(header)):
  print(i-8,header[i])
# Out:
# -8 True
# -7 -32
# -6 2
# -5 16
# -4 52681
# -3 21/01/08
# -2 2008-01-04
# -1 piura
# 0 Time-UT (s)
# 1 GPS Delay (us)
# 2 NAA-V Phase (deg.)
# 3 NAA-V Amp (dB)
# 4 NDK-V Phase (deg.)
# 5 NDK-V Amp (dB)
# 6 NAA-L Phase (deg.)
# 7 NAA-L Amp (dB)
# 8 NDK-L Phase (deg.)
# 9 NDK-L Amp (dB)
# 10 NAU Phase (deg.)
# 11 NAU Amp (dB)
# 12 NLK Phase (deg.)
# 13 NLK Amp (dB)
# 14 NPM Phase (deg.)
# 15 NPM Amp (dB)

# %%
source = header[0:8]
header = header[8:-1]
header
# Out:
# ['Time-UT (s)',
#  'GPS Delay (us)',
#  'NAA-V Phase (deg.)',
#  'NAA-V Amp (dB)',
#  'NDK-V Phase (deg.)',
#  'NDK-V Amp (dB)',
#  'NAA-L Phase (deg.)',
#  'NAA-L Amp (dB)',
#  'NDK-L Phase (deg.)',
#  'NDK-L Amp (dB)',
#  'NAU Phase (deg.)',
#  'NAU Amp (dB)',
#  'NLK Phase (deg.)',
#  'NLK Amp (dB)',
#  'NPM Phase (deg.)']

# %%
source
# Out:
# ['True', '-32', '2', '16', '52681', '21/01/08', '2008-01-04', 'piura']

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2,figsize=(16,5))

for name in [x for x in header if 'Amp' in x]:
  ax[0].plot(fx[0].data[:,0],fx[0].data[:,header.index(name)],label=name)
  
for name in [x for x in header if 'Phase' in x]:
  ax[1].plot(fx[0].data[:,0],fx[0].data[:,header.index(name)],label=name)

plt.suptitle(' Station: ' + source[-1].upper() + '\nVLF - DATE OBS ' + source[-2],y=1.1,fontsize=16)
ax[0].set_xlabel(header[0])
ax[1].set_xlabel(header[0])
ax[0].legend(loc='lower left')
ax[1].legend(loc='upper left')
ax[0].grid()
ax[1].grid()
plt.tight_layout()
plt.show()

# %%
header.index[name]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-95abcff038fa> in <module>
# ----> 1 header.index[name]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
list(range(3,15,2))
